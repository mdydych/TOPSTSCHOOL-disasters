# %%
# !pip install python-dotenv psutil censusdis

# %%
import censusdis.data as ced
import censusdis.maps as cem
from censusdis import states
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt
import os
import psutil
from matplotlib.ticker import FuncFormatter
import arcgis
from arcgis.gis import GIS
from arcgis.map import Map

# %%
# %clear
#Function to check memory usage

def check_memory_usage():
    # Get virtual memory details
    virtual_memory = psutil.virtual_memory()

    # Print cache memory details
    print(f"Used Cache Memory: {virtual_memory.used / (1024 ** 2):.2f} MB")
    print(f"Available Cache Memory: {virtual_memory.available / (1024 ** 2):.2f} MB")

check_memory_usage()
# Out:
# TUsed Cache Memory: 17142.14 MB
# Available Cache Memory: 48393.34 MB

# %%
#Variables to use to pull data from the Census API
#We're using the 2020 Decenial Census and the Demographic and Housing Characteristics dataset


YEAR = 2020
DATASET = 'dec/dhc'

# %%
# Set the environment variable (for testing purposes)
load_dotenv()

# Retrieve the API key from the environment variable
CENSUS_API_KEY = os.getenv("CENSUS_API_KEY")

totalpop = "P1_001N"
vacant = "H3_003N"
hhunit = "H1_001N"

targeted_state = states.PR
variables = ["NAME", "GEO_ID", totalpop, vacant, hhunit]

pr_block = ced.download(
    DATASET,
    YEAR,
    variables,
    state=targeted_state,
    block="*",
    with_geometry=True,
    # tiger_shapefiles_only=True,  ##Optional if you want to use the TIGER shapefiles
    api_key = CENSUS_API_KEY,
)


pr_county = ced.download(
    DATASET,
    YEAR,
    variables,
    state=targeted_state,
    county="*",
    with_geometry=True,
    # tiger_shapefiles_only=True,
    api_key = CENSUS_API_KEY,
)


#Check cache memory usage 
check_memory_usage()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#     result = self._run_cell(
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#     result = runner(coro)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\htran.CIESIN_NT\AppData\Local\Temp\ipykernel_14588\4052249081.py", line 14, in <module>
#     pr_block = ced.download(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\data.py", line 828, in download
#     return _download_remote(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\data.py", line 957, in _download_remote
#     gdf_data = add_geography(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\impl\us_census_shapefiles.py", line 427, in add_geography
#     gdf_shapefile = pd.concat(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py", line 382, in concat
#     op = _Concatenator(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py", line 445, in __init__
#     objs, keys = self._clean_keys_and_objs(objs, keys)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py", line 504, in _clean_keys_and_objs
#     objs_list = list(objs)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\impl\us_census_shapefiles.py", line 428, in <genexpr>
#     individual_shapefile(sub_scope, year)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\impl\us_census_shapefiles.py", line 401, in individual_shapefile
#     gdf = __shapefile_reader(query_year).try_cb_tiger_shapefile(
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py", line 406, in try_cb_tiger_shapefile
#     gdf = self._tiger(shapefile_scope, geography, crs, timeout=timeout)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py", line 152, in _tiger
#     gdf = self._read_shapefile(name, base_url, crs, timeout=timeout)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py", line 86, in _read_shapefile
#     gdf = gpd.read_file(path)
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\geopandas\io\file.py", line 278, in _read_file
#     engine = _check_engine(engine, "'read_file' function")
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\geopandas\io\file.py", line 124, in _check_engine
#     _import_pyogrio()
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\geopandas\io\file.py", line 77, in _import_pyogrio
#     import pyogrio
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pyogrio\__init__.py", line 41, in <module>
#     from pyogrio.geopandas import read_dataframe, write_dataframe
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pyogrio\geopandas.py", line 8, in <module>
#     from pyogrio._compat import HAS_GEOPANDAS, PANDAS_GE_15, PANDAS_GE_20, PANDAS_GE_22
#   File "C:\Users\htran.CIESIN_NT\AppData\Roaming\Python\Python311\site-packages\pyogrio\_compat.py", line 7, in <module>
#     import pyarrow
#   File "d:\Pro\bin\Python\envs\arc-dev\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# MapException                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py:401, in ShapeReader.try_cb_tiger_shapefile(self, shapefile_scope, geography, resolution, crs, timeout)
#     400 try:
# --> 401     gdf = self._cartographic_bound(
#     402         shapefile_scope, geography, resolution, crs, timeout=timeout
#     403     )
#     404 except MapException as e:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py:223, in ShapeReader._cartographic_bound(self, shapefile_scope, geography, resolution, crs, timeout)
#     221     base_url, name = self._post_2010_cb(shapefile_scope, geography, resolution)
# --> 223 gdf = self._read_shapefile(name, base_url, crs, timeout=timeout)
#     225 # Some files on the server, like
#     226 # https://www2.census.gov/geo/tiger/GENZ2010/gz_2010_us_050_00_500k.zip
#     227 # leave the 'FP' suffix of column names.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py:82, in ShapeReader._read_shapefile(self, base_name, base_url, crs, timeout)
#      81 """Read a shapefile."""
# ---> 82 self._auto_fetch_file(base_name, base_url, timeout=timeout)
#      84 path = self._shapefile_full_path(base_name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py:414, in ShapeReader._auto_fetch_file(self, name, base_url, timeout)
#     412     return
# --> 414 self._fetch_file(name, base_url, timeout=timeout)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\censusdis\maps.py:480, in ShapeReader._fetch_file(self, name, base_url, timeout)
#     479 if response.status_code == 404:
# --> 480     raise MapException(
#     481         f"{zip_url} was not found. "
#     482         "The Census Bureau may not publish the shapefile you are looking for for the given year. "
#     483         "Or the file you are looking for may be from a year where a naming convention that censusdis "
#     484         "does not recognize was used."
#     485     )
#     487 headers = response.headers
#
# MapException: https://www2.census.gov/geo/tiger/GENZ2020/shp/cb_2020_72_tabblock_500k.zip was not found. The Census Bureau may not publish the shapefile you are looking for for the given year. Or the file you are looking for may be from a year where a naming convention that censusdis does not recognize was used.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# TUsed Cache Memory: 17200.82 MB
# Available Cache Memory: 48334.66 MB

# %%
#With tiger shapefiles variable

# Plot the map with the given parameters
ax = cem.plot_map(pr_block, 
                    column=pr_block[vacant]/pr_block[hhunit]*100, 
                    # edgecolor="black", 
                    cmap="PRGn", 
                    legend=True, 
                    figsize=(20, 20),
                    legend_kwds={"format": FuncFormatter(lambda x, pos: f"{x:,.1f}%")},
                    )
_ = ax.set_title("Percentage of vacancy units in Puerto Rico in 2020")

#Add county boundary to the map

ax = cem.plot_map(pr_county.boundary, color="lightgrey", linewidth=0.5, ax=ax)

# %%
#Without tiger shapefiles variable

# Plot the map of vacancy percentage in Puerto Rico
ax = cem.plot_map(pr_block, 
                    column=pr_block[vacant]/pr_block[hhunit]*100, 
                    # edgecolor="black", 
                    cmap="PRGn", 
                    legend=True, 
                    figsize=(20, 20),
                    legend_kwds={"format": FuncFormatter(lambda x, pos: f"{x:,.1f}%")},
                    )
_ = ax.set_title("Percentage of vacancy units in Puerto Rico in 2020")

#Add county boundary to the map
ax = cem.plot_map(pr_county.boundary, color="lightgrey", linewidth=0.5, ax=ax)

# %%
#Compare 2010 and 2020 vacancy data

pr_block_2010 = ced.download(
    "dec/sf1",
    2010,
    ["NAME", "GEO_ID", "P010001", "H003003", "H001001"],
    state=targeted_state,
    county="*",
    with_geometry=True,
    # tiger_shapefiles_only=True,
    api_key = CENSUS_API_KEY,
    # remove_water = True,
)


pr_block_2020 = ced.download(
    DATASET,
    YEAR,
    variables,
    state=targeted_state,
    county="*",
    with_geometry=True,
    # tiger_shapefiles_only=True,
    api_key = CENSUS_API_KEY,
    # remove_water = True,
)

check_memory_usage()
# Out:
# TUsed Cache Memory: 17411.59 MB
# Available Cache Memory: 48123.90 MB

# %%
gdf_both_years = pr_block_2020.merge(pr_block_2010, on=["GEO_ID", "NAME"] , suffixes=("_2020", "_2010"))

# %%
vacant_variable_2020 = vacant
vacant_variable_2010 = "H003003"
total_change_percent = vacant + "_change_percent"
total_change = vacant + "_change"

# %%
gdf_both_years[total_change] = (
                                gdf_both_years[vacant_variable_2020]
                                  - gdf_both_years[vacant_variable_2010]
)

gdf_both_years[total_change_percent] = (
                                        100 
                                        * gdf_both_years[total_change]
                                        / gdf_both_years[vacant_variable_2010]
)
# Classify the data by quantile
gdf_both_years['quantile'] = pd.qcut(gdf_both_years[total_change], q=5, labels=False)

# %%
gdf_both_years.set_geometry("geometry_2020", inplace=True)
ax = cem.plot_map(gdf_both_years, 
                  gdf_both_years["quantile"], 
                  cmap="coolwarm", 
                  legend=True, 
                  figsize=(20, 20), 
                  linewidth=0.25, 
                #   legend_kwds={"format": FuncFormatter(lambda x, pos: f"{x:+,.1f}%")},
                  )

_ = ax.set_title("Change in the number of vacant units in Puerto Rico between 2010 and 2020")
#Add county boundary to the map
cem.plot_map(pr_county.boundary, color="white", linewidth=0.5, ax=ax)
# Adjust the legend position to be at the bottom center
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3)

plt.show()
# Out:
# C:\Users\htran.CIESIN_NT\AppData\Local\Temp\ipykernel_14588\3964711460.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=3)

# %%
gdf_both_years.head()
# Out:
#   STATE_2020 COUNTY_2020                                 NAME          GEO_ID  \
# 0         72         001      Adjuntas Municipio, Puerto Rico  0500000US72001
# 1         72         003        Aguada Municipio, Puerto Rico  0500000US72003
# 2         72         005     Aguadilla Municipio, Puerto Rico  0500000US72005
# 3         72         007  Aguas Buenas Municipio, Puerto Rico  0500000US72007
# 4         72         009      Aibonito Municipio, Puerto Rico  0500000US72009
#
#    P1_001N  H3_003N  H1_001N  \
# 0    18020      930     7911
# 1    38136     2300    17362
# 2    55101     4911    27862
# 3    24223     1129    10553
# 4    24637      876    10953
#
#                                        geometry_2020 STATE_2010 COUNTY_2010  \
# 0  POLYGON ((-66.83724 18.19271, -66.83358 18.194...         72         001
# 1  POLYGON ((-67.23915 18.3755, -67.22803 18.3780...         72         003
# 2  POLYGON ((-67.16914 18.47605, -67.16697 18.482...         72         005
# 3  POLYGON ((-66.1892 18.2598, -66.18869 18.26074...         72         007
# 4  POLYGON ((-66.31804 18.13058, -66.31574 18.134...         72         009
#
#    P010001  H003003  H001001  \
# 0    14484     1274     8125
# 1    32033     3102    18258
# 2    46516     4878    28430
# 3    21474     1450    11490
# 4    19662     1042    10409
#
#                                        geometry_2010  H3_003N_change  \
# 0  POLYGON ((-66.83569 18.18883, -66.83589 18.190...            -344
# 1  POLYGON ((-67.17665 18.4055, -67.17186 18.4084...            -802
# 2  POLYGON ((-67.16901 18.47172, -67.16901 18.476...              33
# 3  POLYGON ((-66.11466 18.21207, -66.11704 18.211...            -321
# 4  POLYGON ((-66.23184 18.09577, -66.2349 18.0942...            -166
#
#    H3_003N_change_percent  quantile
# 0              -27.001570         1
# 1              -25.854288         0
# 2                0.676507         3
# 3              -22.137931         1
# 4              -15.930902         1

# %%
gis = GIS()

# %%
from arcgis.map import Map
empty_webmap = Map()

# %%
lecz_layer = gis.content.search("lecz", item_type="Web Map")[6]
lecz_layer
# Out:
# <Item title:"Low Elevation Coastal Zone (LECZ) Urban-Rural Population and Land Area Estimates, Version 3" type:Web Map owner:NASA_Earthdata>

# %%
lecz_map = Map(item=lecz_layer)

# %%
lecz_map
# Out:
# Map(extent={'spatialReference': {'latestWkid': 3857, 'wkid': 102100}, 'xmax': 17806770.109310027, 'xmin': -428…
